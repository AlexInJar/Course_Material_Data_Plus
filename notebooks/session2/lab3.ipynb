# %% [markdown]
# # Scraping Twitter data with snscrape

# %% [markdown]
# ## 0. Set up
# **snscrape** is a scraper for social networking services. It currently supports lots of services such as Twitter, Facebook, Instagram, etc. It scrapes things like user profiles, hashtags, or searches and returns the discovered items, e.g. the relevant posts. More information about snscrape can be viewed from its [GitHub](https://github.com/JustAnotherArchivist/snscrape) site.
#
# **Note: you may need to connect the Duke vpn (portal.duke.edu) to finish this lab.**

# %%
# install snscrape using pip
# !pip3 install snscrape

# %%
# import libraries
import snscrape.modules.twitter as sntwitter
import snscrape.modules.twitter

import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Overview
#
# In today's lab, we are going to use snscrape to scrape data from twitter. You will learn to scrape tweets from:
# 1. text search query
# 2. a specific user
#
# Snscrape provides many useful attributes available through snscrape Twitter object [(Beck, 2020)](https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af). You might need some of the above attributes when scraping data for your group projects.
# * url: Permalink pointing to tweet location
# * date: The date on which the tweet was created
# * content: The text content of the tweet
# * id: The id of the tweet
# * user: User object containing the following data: username, displayname, id, description, descriptionUrls, verified, created, followersCount, friendsCount, statusesCount, favouritesCount, listedCount, location, protected, linkUrl, profileImageUrl, profileBannerUrl
# * replyCount: The count of replies
# * retweetCount: The count of retweets
# * likeCount: The count of likes
# * quoteCount: The count of users that quoted the tweet and replied
# * conversationId: Appears to be the same as tweet id
# * lang: Machine generated, assumed language of the tweet
# * source: Where tweet was posted from (e.g., iPhone, Andriod, etc.)
# * retweetedTweet: The id of the original tweet (if it is a retweet)
# * mentionedUsers: The user objects of any mentioned user in the tweet

# %% [markdown]
# ##  2. Scrape tweets from a text search query
#
# The queried text could be certain keywords and hashtags.

# %% [markdown]
# ###  Example 1
# In this example, we scrape 10 tweets with the **#stopasianhate** hashtag with at least three likes `min_faves:3`. We save the scraped tweets with its posted date `tweet.date`, text content `tweet.content`, poster's location `tweet.user.location`, and the number of received likes `tweet.likeCount` into a dataframe.

# %%
# create a list to append twitter data to
tweets_list1 = []

# use TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('Chinese virus since:2022-02-15 until:2022-03-16 min_faves:0').get_items()):
    if i >= 3000:
        break
    tweets_list1.append([tweet.date,  tweet.content, tweet.user.location, tweet.likeCount])

# %%
# create a dataframe to view the result
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Date', 'Content', 'User\'s location', '# of likes'])
tweets_df1
# Out:
#                           Date  \
# 0    2022-03-15 23:37:26+00:00
# 1    2022-03-15 23:29:36+00:00
# 2    2022-03-15 23:18:26+00:00
# 3    2022-03-15 23:12:37+00:00
# 4    2022-03-15 23:10:06+00:00
# ...                        ...
# 2721 2022-02-15 00:53:17+00:00
# 2722 2022-02-15 00:34:44+00:00
# 2723 2022-02-15 00:24:20+00:00
# 2724 2022-02-15 00:18:35+00:00
# 2725 2022-02-15 00:17:18+00:00
#
#                                                 Content  \
# 0     Chinese virus cases climb, raise threat of tra...
# 1     Chinese virus cases climb, raise threat of tra...
# 2     VP Snickers hubby has the chinese virus too......
# 2272  Now that the local body elections are over , n...
# 1250  @chitraSD @ndtvfeed Will sanctions be applied ...
# 2428  @ConsPostingLs you know, it is funny how "chin...
# 1017  A Chinese virus, you wear masks made in China,...
# 1175  But don't call it "the Chinese virus" https://...
# 2690  #chinesevirus\n#chinesevaccine \n#chinaliedpeo...
# 2358              It was NEVER about the Chinese virus.
# 1441  INBOX: Jewish and AAPI groups in region demand...
# 74    Americans spent the last 2 years debating weth...
# 1186  I’m very sorry to cuss like this.\n\nBut consi...
# 803   Turns out there was a cure for COVID, all it t...
# 2553  JB 不允许称“Chinese virus”，曾经让很多华裔感到温暖，华裔中高达70%以上的...
# 1924  @TheOnion "My Manly Potency Protects Me From T...
# 528   #Bengaluru After a long time (thanks to the #C...
# 1380  'Early in the corona era the historian David S...
#
#                      User's location  # of likes
# 772   Unceded Coast Salish Territory        9694
# 680                            India         878
# 2423                           India         746
# 1387                           India         741
# 180                                          621
# 2171                      चुरु, भारत         621
# 231               Tamil Nadu . India         427
# 2337                          India          381
# 1613                  Washington, DC         308
# 1656               Glasgow, Scotland         291
# 349                   Washington, DC         256
# 994                                          249
# 1936           Spielfeld, Österreich         249
# 2441                   Las Vegas, NV         242
# 1221                                         234
# 2272              Tamil Nadu . India         187
# 1250                           India         174
# 2428                            1990         173
# 1017                      Denver, CO         149
# 1175                                         140
# 2690                New Delhi, India         136
# 2358                      Antarctica         121
# 1441       Lovely Pacific Northwest          117
# 74                                           107
# 1186                        Tampa FL         106
# 803                  Gibsonburg Ohio         101
# 2553                                          92
# 1924                      London, UK          90
# 528                 Bengaluru, India          87
# 1380                          London          76

# %%
# tweets_df1.loc[np.random.randint(len(tweets_df1)),'Content']
tweets_df1.loc[994,'Content']
# Out:
# 'Remember: Don\'t call it "the Chinese virus." https://t.co/FPWtqgIheo'

# %%
## Output example1 csv
tweets_df1.to_csv('eg1.csv')

# %% [markdown]
# ### Example 2
#
# In this example, we scrape tweets that contains keywords in the phrase **let's go duke** around the date of a basketball match. We save the scraped tweets with its posted date `tweet.date`, text content `tweet.content`, and the user's location `tweet.user.location` into a dataframe.

# %%
# create a list to append twitter data to
tweets_list2 = []

# use TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('let\'s go duke since:2021-11-12 until:2021-11-13').get_items()):
    tweets_list2.append([tweet.date, tweet.content, tweet.user.location])

# %%
# create a dataframe to view the result
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Date', 'Content', 'User\'s location'])
tweets_df2
# Out:
#                         Date  \
# 0  2021-11-12 23:59:21+00:00
# 1  2021-11-12 23:58:46+00:00
# 2  2021-11-12 23:57:29+00:00
# 3  2021-11-12 23:56:40+00:00
# 4  2021-11-12 23:55:37+00:00
# 5  2021-11-12 23:54:42+00:00
# 6  2021-11-12 23:53:25+00:00
# 7  2021-11-12 23:51:58+00:00
# 8  2021-11-12 23:51:13+00:00
# 9  2021-11-12 23:48:41+00:00
# 10 2021-11-12 23:48:02+00:00
# 11 2021-11-12 23:47:43+00:00
# 30  Girls’ Diving\nState\nKalina’s first dive!\nGr...
# 31  Let’s go @DaytonWBB‼️\n\nBe sure to show up to...
# 32             Let’s go Duke! https://t.co/FaXmZIXuO0
# 33  Duke bound!  Here we come, Cameron. Thank you ...
# 34  Happy Birthday Paolo 😈😈💙💙 Let’s go Duke #GameD...
# 35  🔵 Gameday! Let's Go Duke! 🔵\n\n🏆 Veterans Day ...
# 36  @Zlanier21 @sarahlongthorne Dukes up. SJ let’s...
# 37  @Duke_kanbai_ @Eghyofbenin I think I need to s...
# 38                  It’s game day! \n\nLet’s go Duke!
# 39  @DukeMBB @UpdateDuke @DukeDigest @dukepbp @duk...
# 40  @Qu3stion_84 @DukeOfSexy @rainboom16 @HimuraHi...
# 41  Happy Veterans Day!! First game in Cameron tom...
# 42  @TylerMeinerding Kenny Anderson throwback is 🤮...
#
#               User's location
# 0        My Own Personal Hell
# 1
# 2              Germantown, MD
# 3                     #SI6HTS
# 4                 Raleigh, NC
# 5
# 6
# 7                         252
# 8             San Antonio, TX
# 9
# 10                  Tampa, FL
# 11              Harrisburg PA
# 12                  Uptown Dc
# 13        Fort Lauderdale, FL
# 14                 RGF Island
# 15                 Durham, NC
# 16                  North KaK
# 17  The Greater Triangle Area
# 18              Harrisburg PA
# 19
# 20        in my right mind :)
# 21                       206📍
# 22
# 23                ✨Illinois ✨
# 24              Harrisburg PA
# 25
# 26
# 27                 Dallas, TX
# 28                Atlanta, GA
# 29
# 30               Elmhurst, IL
# 31                 Dayton, OH
# 32
# 33
# 34                  Tampa, FL
# 35                 Durham, NC
# 36   Seattle, Washington, USA
# 37             iCONs Republic
# 38               Vincent Ohio
# 39                 World Wide
# 40
# 41    Cameron Indoor Stadium
# 42

# %%
## Output example1 csv
tweets_df2.to_csv('eg2.csv')

# %% [markdown]
# ## 3. Scrape tweets from a specific user

# %% [markdown]
# ### Example 3

# %% [markdown]
# In this example, we scrape the latest 100 tweets posted by the Twitter user **@DukeKunshan**. We save the scraped tweets with its posted date `tweet.date`, text content `tweet.content`, and username `tweet.user.username` into a dataframe.

# %%
# create a list to append twitter data to
tweets_list3 = []

# use TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:DukeKunshan').get_items()):
    if i >= 100:
        break
    tweets_list3.append([tweet.date, tweet.content, tweet.user.username])

# %%
# create a dataframe to view the result
tweets_df3 = pd.DataFrame(tweets_list3, columns=['Date', 'Content', 'Username'])
tweets_df3
# Out:
#                         Date  \
# 0  2022-03-28 10:00:05+00:00
# 1  2022-03-24 01:00:05+00:00
# 2  2022-03-23 02:30:02+00:00
# 3  2022-03-16 02:00:05+00:00
# 4  2022-03-15 15:30:12+00:00
# ..                       ...
# 95 2021-09-22 13:00:43+00:00
# 96 2021-09-20 03:30:02+00:00
# 97 2021-09-19 01:00:10+00:00
# 98 2021-09-16 07:00:05+00:00
# 99 2021-09-13 03:30:01+00:00
#
#                                               Content     Username
# 0   Many graduating students from DKU’s Master of ...  DukeKunshan
# 1   📢 Starting tomorrow: Discrete Math Seminar\n\n...  DukeKunshan
# 2   📢  Starting tomorrow: Duke Kunshan University ...  DukeKunshan
# 3   📢  Save the date: Duke Kunshan University 2022...  DukeKunshan
# 4   Check out these photos of construction progres...  DukeKunshan
# ..                                                ...          ...
# 95  There’s nothing better than a good roommate at...  DukeKunshan
# 96  A new art book co-edited by Duke Kunshan profe...  DukeKunshan
# 97  Wishing everyone a happy Mid-Autumn Festival!\...  DukeKunshan
# 98  📢  Starting tomorrow: DKU Career Fair | Fall 2...  DukeKunshan
# 99  After Covid-19 made international travel almos...  DukeKunshan
#
# [100 rows x 3 columns]

# %%
tweets_df3.to_csv('eg3.csv')

# %% [markdown]
# ## Exercise

# %% [markdown]
# ## Here scrape all posts from 2021-10-10 to 2021-11-30 that mention 'covid modeling'

# %%
tweets_list_exc = []

# use TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('Covid modeling since:2021-10-10 until:2021-11-30').get_items()):
    tweets_list_exc.append([tweet.date, tweet.content, tweet.user.location])

# %%
tweets_df_ex = pd.DataFrame(tweets_list_exc, columns=['Date', 'Content', 'Username'])
tweets_df_ex
# Out:
#                          Date  \
# 0   2021-11-29 23:42:12+00:00
# 1   2021-11-29 23:42:02+00:00
# 2   2021-11-29 23:04:11+00:00
# 3   2021-11-29 22:50:29+00:00
# 4   2021-11-29 22:48:18+00:00
# ..                        ...
# 963 2021-10-10 16:15:54+00:00
# 964 2021-10-10 15:31:21+00:00
# 965 2021-10-10 05:51:59+00:00
# 966 2021-10-10 05:15:48+00:00
# 967 2021-10-10 05:00:03+00:00
#
#                                                Content  \
# 0    New SARS-CoV-2 modeling suggests virus will re...
# 1    @medrxivpreprint New SARS-CoV-2 modeling sugge...
# 2    Join us on Friday, Dec.3 at 2pm HST for a semi...
# 3    @ZaleskiLuke @GOP Trump failed abysmally w/ hi...
# 4    @Siobhan23738909 @JCWI_UK @JolyonMaugham @Bori...
# ..                                                 ...
# 963  The COVID vaccine clinic is open after he Farm...
# 964  @BernieHancock69 @DavidStaplesYEG The same poo...
# 965  how rude it is that i have to do a project mod...
# 966  Covid modeling update...\n\nWe now go live to ...
# 967  #HorganTheCoward left BC as forest fires burne...
#
#                           Username
# 0
# 1
# 2            University of Hawai‘i
# 3                              USA
# 4    the future the past never now
# ..                             ...
# 963                  West Fork, AR
# 964        I live on Freehold Land
# 965          scorpio ☼ sag ☽ cap ➶
# 966   Taranaki Region, New Zealand
# 967
#
# [968 rows x 3 columns]

# %%
tweets_df_ex.to_csv('ex_covid_modeling.csv')

# %% [markdown]
# # Optional: Scraping Weibo data

# %% [markdown]
# If your project's topic falls in the environment of Chinese society, you may need to scrape data from [Weibo](http://www.weibo.com/) instead of Twitter. A simple, easy-to-use API can be found [here](https://github.com/dataabc/weibo-search). If you can NOT sign up for an account but want a cookie to use this API, you can e-mail me at rb347@duke.edu.
